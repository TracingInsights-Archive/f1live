# %%
# !pip install fastf1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting fastf1
#   Downloading fastf1-3.5.1-py3-none-any.whl (150 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.9/150.9 KB 7.0 MB/s eta 0:00:00
# Collecting scipy<2.0.0,>=1.8.1
#   Downloading scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 35.6 MB/s eta 0:00:0000:0100:01
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.12.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 136.3 MB/s eta 0:00:00
# Collecting numpy<3.0.0,>=1.23.1
#   Downloading numpy-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 92.3 MB/s eta 0:00:0000:0100:01
# Collecting websockets<14,>=10.3
#   Downloading websockets-13.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 KB 62.2 MB/s eta 0:00:00
# Collecting matplotlib<4.0.0,>=3.5.1
#   Downloading matplotlib-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 140.3 MB/s eta 0:00:00a 0:00:01
# Collecting timple>=0.1.6
#   Downloading timple-0.1.8-py3-none-any.whl (17 kB)
# Requirement already satisfied: python-dateutil in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from fastf1) (2.9.0.post0)
# Collecting requests>=2.28.1
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 KB 28.8 MB/s eta 0:00:00
# Collecting requests-cache>=1.0.0
#   Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 KB 29.6 MB/s eta 0:00:00
# Collecting pandas<3.0.0,>=1.4.1
#   Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 138.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (2.4.7)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pillow>=8
#   Downloading pillow-11.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 150.6 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 134.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (24.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.56.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 176.1 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (324 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 KB 99.2 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.9/507.9 KB 89.3 MB/s eta 0:00:00
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.8/346.8 KB 111.8 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil->fastf1) (1.16.0)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 KB 54.5 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.1/146.1 KB 58.9 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 KB 42.3 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.10-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 KB 36.7 MB/s eta 0:00:00
# Collecting cattrs>=22.2
#   Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 KB 34.4 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.5 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests-cache>=1.0.0->fastf1) (4.3.6)
# Collecting url-normalize>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting attrs>=21.2
#   Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 KB 32.6 MB/s eta 0:00:00
# Requirement already satisfied: exceptiongroup>=1.1.1 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from cattrs>=22.2->requests-cache>=1.0.0->fastf1) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from cattrs>=22.2->requests-cache>=1.0.0->fastf1) (4.12.2)
# Installing collected packages: pytz, websockets, urllib3, url-normalize, tzdata, rapidfuzz, pillow, numpy, kiwisolver, idna, fonttools, cycler, charset-normalizer, certifi, attrs, scipy, requests, pandas, contourpy, cattrs, requests-cache, matplotlib, timple, fastf1
# Successfully installed attrs-25.3.0 cattrs-24.1.2 certifi-2025.1.31 charset-normalizer-3.4.1 contourpy-1.3.1 cycler-0.12.1 fastf1-3.5.1 fonttools-4.56.0 idna-3.10 kiwisolver-1.4.8 matplotlib-3.10.1 numpy-2.2.3 pandas-2.2.3 pillow-11.1.0 pytz-2025.1 rapidfuzz-3.12.2 requests-2.32.3 requests-cache-1.2.1 scipy-1.15.2 timple-0.1.8 tzdata-2025.1 url-normalize-1.4.3 urllib3-2.3.0 websockets-13.1

# %%
# !pip install livef1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting livef1
#   Downloading livef1-0.1.45-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 KB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: Requests==2.32.3 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from livef1) (2.32.3)
# Collecting ujson==5.10.0
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 KB 9.3 MB/s eta 0:00:00
# Collecting websockets==13.0.1
#   Downloading websockets-13.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.3/157.3 KB 20.2 MB/s eta 0:00:00
# Collecting jellyfish==1.1.3
#   Downloading jellyfish-1.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (347 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.4/347.4 KB 44.9 MB/s eta 0:00:00
# Requirement already satisfied: setuptools==59.6.0 in /usr/lib/python3/dist-packages (from livef1) (59.6.0)
# Requirement already satisfied: python_dateutil==2.9.0.post0 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from livef1) (2.9.0.post0)
# Collecting scipy==1.11.4
#   Downloading scipy-1.11.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 34.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas==2.2.3 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from livef1) (2.2.3)
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 86.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tzdata>=2022.7 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pandas==2.2.3->livef1) (2025.1)
# Requirement already satisfied: pytz>=2020.1 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pandas==2.2.3->livef1) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python_dateutil==2.9.0.post0->livef1) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from Requests==2.32.3->livef1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from Requests==2.32.3->livef1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from Requests==2.32.3->livef1) (2025.1.31)
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from Requests==2.32.3->livef1) (3.4.1)
# Installing collected packages: websockets, ujson, numpy, jellyfish, scipy, livef1
#   Attempting uninstall: websockets
#     Found existing installation: websockets 13.1
#     Uninstalling websockets-13.1:
#       Successfully uninstalled websockets-13.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.3
#     Uninstalling numpy-2.2.3:
#       Successfully uninstalled numpy-2.2.3
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.2
#     Uninstalling scipy-1.15.2:
#       Successfully uninstalled scipy-1.15.2
# Successfully installed jellyfish-1.1.3 livef1-0.1.45 numpy-1.26.4 scipy-1.11.4 ujson-5.10.0 websockets-13.0.1

# %%
import livef1 as livef1
season = livef1.get_season(season=2025)
print(season)
# Out:
#              season_year meeting_code  meeting_number meeting_location  \
# meeting_key
# 1253                2025    F12025T01               1           Sakhir
# 1253                2025    F12025T01               1           Sakhir
# 1253                2025    F12025T01               1           Sakhir
#
#                                       meeting_offname        meeting_name  \
# meeting_key
# 1253         FORMULA 1 ARAMCO PRE-SEASON TESTING 2025  Pre-Season Testing
# 1253         FORMULA 1 ARAMCO PRE-SEASON TESTING 2025  Pre-Season Testing
# 1253         FORMULA 1 ARAMCO PRE-SEASON TESTING 2025  Pre-Season Testing
#
#              meeting_country_key meeting_country_code meeting_country_name  \
# meeting_key
# 1253                          36                  BRN              Bahrain
# 1253                          36                  BRN              Bahrain
# 1253                          36                  BRN              Bahrain
#
#              meeting_circuit_key meeting_circuit_shortname  session_key  \
# meeting_key
# 1253                          63                    Sakhir         9683
# 1253                          63                    Sakhir         9684
# 1253                          63                    Sakhir         9685
#
#             session_type session_name   session_startDate     session_endDate  \
# meeting_key
# 1253          Practice 1        Day 1 2025-02-26 10:00:00 2025-02-26 19:00:00
# 1253          Practice 2        Day 2 2025-02-27 10:00:00 2025-02-27 19:00:00
# 1253          Practice 3        Day 3 2025-02-28 10:00:00 2025-02-28 19:00:00
#
#             gmtoffset                                               path
# meeting_key
# 1253         03:00:00  2025/2025-02-28_Pre-Season_Testing/2025-02-26_...
# 1253         03:00:00  2025/2025-02-28_Pre-Season_Testing/2025-02-27_...
# 1253         03:00:00  2025/2025-02-28_Pre-Season_Testing/2025-02-28_...

# %%
season
# Out:
#              season_year meeting_code  meeting_number meeting_location  \
# meeting_key
# 1253                2025    F12025T01               1           Sakhir
# 1253                2025    F12025T01               1           Sakhir
# 1253                2025    F12025T01               1           Sakhir
#
#                                       meeting_offname        meeting_name  \
# meeting_key
# 1253         FORMULA 1 ARAMCO PRE-SEASON TESTING 2025  Pre-Season Testing
# 1253         FORMULA 1 ARAMCO PRE-SEASON TESTING 2025  Pre-Season Testing
# 1253         FORMULA 1 ARAMCO PRE-SEASON TESTING 2025  Pre-Season Testing
#
#              meeting_country_key meeting_country_code meeting_country_name  \
# meeting_key
# 1253                          36                  BRN              Bahrain
# 1253                          36                  BRN              Bahrain
# 1253                          36                  BRN              Bahrain
#
#              meeting_circuit_key meeting_circuit_shortname  session_key  \
# meeting_key
# 1253                          63                    Sakhir         9683
# 1253                          63                    Sakhir         9684
# 1253                          63                    Sakhir         9685
#
#             session_type session_name   session_startDate     session_endDate  \
# meeting_key
# 1253          Practice 1        Day 1 2025-02-26 10:00:00 2025-02-26 19:00:00
# 1253          Practice 2        Day 2 2025-02-27 10:00:00 2025-02-27 19:00:00
# 1253          Practice 3        Day 3 2025-02-28 10:00:00 2025-02-28 19:00:00
#
#             gmtoffset                                               path
# meeting_key
# 1253         03:00:00  2025/2025-02-28_Pre-Season_Testing/2025-02-26_...
# 1253         03:00:00  2025/2025-02-28_Pre-Season_Testing/2025-02-27_...
# 1253         03:00:00  2025/2025-02-28_Pre-Season_Testing/2025-02-28_...
#              season_year meeting_code  meeting_number meeting_location  \
# meeting_key
# 1253                2025    F12025T01               1           Sakhir
# 1253                2025    F12025T01               1           Sakhir
# 1253                2025    F12025T01               1           Sakhir
#
#                                       meeting_offname        meeting_name  \
# meeting_key
# 1253         FORMULA 1 ARAMCO PRE-SEASON TESTING 2025  Pre-Season Testing
# 1253         FORMULA 1 ARAMCO PRE-SEASON TESTING 2025  Pre-Season Testing
# 1253         FORMULA 1 ARAMCO PRE-SEASON TESTING 2025  Pre-Season Testing
#
#              meeting_country_key meeting_country_code meeting_country_name  \
# meeting_key
# 1253                          36                  BRN              Bahrain
# 1253                          36                  BRN              Bahrain
# 1253                          36                  BRN              Bahrain
#
#              meeting_circuit_key meeting_circuit_shortname  session_key  \
# meeting_key
# 1253                          63                    Sakhir         9683
# 1253                          63                    Sakhir         9684
# 1253                          63                    Sakhir         9685
#
#             session_type session_name   session_startDate     session_endDate  \
# meeting_key
# 1253          Practice 1        Day 1 2025-02-26 10:00:00 2025-02-26 19:00:00
# 1253          Practice 2        Day 2 2025-02-27 10:00:00 2025-02-27 19:00:00
# 1253          Practice 3        Day 3 2025-02-28 10:00:00 2025-02-28 19:00:00
#
#             gmtoffset                                               path
# meeting_key
# 1253         03:00:00  2025/2025-02-28_Pre-Season_Testing/2025-02-26_...
# 1253         03:00:00  2025/2025-02-28_Pre-Season_Testing/2025-02-27_...
# 1253         03:00:00  2025/2025-02-28_Pre-Season_Testing/2025-02-28_...

# %%
from livef1.adapters.realtime_client import RealF1Client

client = RealF1Client(
    topics=["RaceControlMessages"],
    log_file_name="./output.json"  # Optional: log incoming data
)

# %%
@client.callback("basic_handler")
async def handle_data(records):
    print(records)

# %%
import datetime

@client.callback("log_handler")
async def log_with_timestamp(records):
    with open("data_with_timestamp.log", "a") as f:
        for record in records:
            timestamp = datetime.datetime.now().isoformat()
            f.write(f"{timestamp} - {record}\n")

# %%
client.run()  # Starts the client and begins receiving data
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 client.run()  # Starts the client and begins receiving data
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages/livef1/adapters/realtime_client.py:207, in RealF1Client.run(self)
#     203 """
#     204 Start the client in asynchronous mode.
#     205 """
#     206 start = time.time()
# --> 207 self._async_engine_run()
#     208 logger.info(f"Client have run for {(time.time() - start):.2f} seconds.")
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages/livef1/adapters/realtime_client.py:215, in RealF1Client._async_engine_run(self)
#     211 """
#     212 Execute the asynchronous engine.
#     213 """
#     214 try:
# --> 215     asyncio.run(self._async_run())
#     216 except KeyboardInterrupt:
#     217     logger.info("Keyboard interrupt - exiting...")
#
# File /usr/lib/python3.10/asyncio/runners.py:33, in run(main, debug)
#       9 """Execute the coroutine and return the result.
#      10
#      11 This function runs the passed coroutine, taking care of
#    (...)
#      30     asyncio.run(main())
#      31 """
#      32 if events._get_running_loop() is not None:
# ---> 33     raise RuntimeError(
#      34         "asyncio.run() cannot be called from a running event loop")
#      36 if not coroutines.iscoroutine(main):
#      37     raise ValueError("a coroutine was expected, got {!r}".format(main))
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
import fastf1

event = fastf1.get_event(2025, 1)
event
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (36.0 KB) /home/gitpod/.cache/fastf1
# RoundNumber                                                          1
# Country                                                      Australia
# Location                                                     Melbourne
# OfficialEventName    FORMULA 1 LOUIS VUITTON AUSTRALIAN GRAND PRIX ...
# EventDate                                          2025-03-16 00:00:00
# EventName                                        Australian Grand Prix
# EventFormat                                               conventional
# Session1                                                    Practice 1
# Session1Date                                 2025-03-14 12:30:00+11:00
# Session1DateUtc                                    2025-03-14 01:30:00
# Session2                                                    Practice 2
# Session2Date                                 2025-03-14 16:00:00+11:00
# Session2DateUtc                                    2025-03-14 05:00:00
# Session3                                                    Practice 3
# Session3Date                                 2025-03-15 12:30:00+11:00
# Session3DateUtc                                    2025-03-15 01:30:00
# Session4                                                    Qualifying
# Session4Date                                 2025-03-15 16:00:00+11:00
# Session4DateUtc                                    2025-03-15 05:00:00
# Session5                                                          Race
# Session5Date                                 2025-03-16 15:00:00+11:00
# Session5DateUtc                                    2025-03-16 04:00:00
# F1ApiSupport                                                      True
# Name: 1, dtype: object

# %%
import fastf1

session = fastf1.core.Session(event, 'Practice 1', True)
session
# Out:
# 2025 Season Round 1: Australian Grand Prix - Practice 1

# %%
session.race_control_messages()
# Out:
# ---------------------------------------------------------------------------
# DataNotLoadedError                        Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 session.race_control_messages()
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages/fastf1/core.py:1357, in Session.race_control_messages(self)
#    1350 @property
#    1351 def race_control_messages(self):
#    1352     """:class:`pandas.Dataframe`: Race Control messages as returned by
#    1353     :func:`fastf1.api.race_control_messages`
#    1354
#    1355     Data is available after calling `Session.load` with ``messages=True``
#    1356     """
# -> 1357     return self._get_property_warn_not_loaded('_race_control_messages')
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages/fastf1/core.py:1249, in Session._get_property_warn_not_loaded(self, name)
#    1247 def _get_property_warn_not_loaded(self, name):
#    1248     if not hasattr(self, name):
# -> 1249         raise DataNotLoadedError(
#    1250             "The data you are trying to access has not been loaded yet. "
#    1251             "See `Session.load`"
#    1252         )
#    1253     return getattr(self, name, None)
#
# DataNotLoadedError: The data you are trying to access has not been loaded yet. See `Session.load`

# %%
fastf1.livetiming.data.LiveTimingData().load()
# Out:
# data           INFO 	Reading live timing data from recording. This may take a bit.

# %%
import fastf1
from fastf1.livetiming.data import LiveTimingData

livedata = LiveTimingData('saved_data.txt')
session = fastf1.get_session(2025, 1, 1)
session.load(livedata=livedata)
# Out:
# core           INFO 	Loading data for Australian Grand Prix - Practice 1 [v3.5.1]
# req            INFO 	No cached data found for session_info. Loading data...
# data           INFO 	Reading live timing data from recording. This may take a bit.
# logger      WARNING 	Failed to load session info data!
# req            INFO 	No cached data found for driver_info. Loading data...
# data           INFO 	Reading live timing data from recording. This may take a bit.
# core        WARNING 	Failed to load extended driver information!
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# core        WARNING 	Failed to load driver list and session results!
# req            INFO 	No cached data found for session_status_data. Loading data...
# data           INFO 	Reading live timing data from recording. This may take a bit.
# logger      WARNING 	Failed to load session status data!
# req            INFO 	No cached data found for track_status_data. Loading data...
# data           INFO 	Reading live timing data from recording. This may take a bit.
# logger      WARNING 	Failed to load track status data!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# data           INFO 	Reading live timing data from recording. This may take a bit.
# logger      WARNING 	Failed to load timing data!
# req            INFO 	No cached data found for car_data. Loading data...
# data           INFO 	Reading live timing data from recording. This may take a bit.
# logger      WARNING 	Failed to load telemetry data!
# req            INFO 	No cached data found for weather_data. Loading data...
# data           INFO 	Reading live timing data from recording. This may take a bit.
# logger      WARNING 	Failed to load weather data!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# data           INFO 	Reading live timing data from recording. This may take a bit.
# logger      WARNING 	Failed to load race control messages!
# core           INFO 	Finished loading data for 0 drivers: []

# %%
session
# Out:
# 2025 Season Round 1: Australian Grand Prix - Practice 1

# %%
path = session.api_path

# %%
fastf1.api.race_control_messages(path, response=None, livedata=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 fastf1.api.race_control_messages(path, response=None, livedata=None)
#
# AttributeError: module 'fastf1' has no attribute 'api'

# %%
'https://api.openf1.org/v1/race_control?meeting_key%3E=latest'

# %%
# !pip install urllib3
# Out:
# Requirement already satisfied: urllib3 in /home/gitpod/.pyenv/versions/3.12.9/lib/python3.12/site-packages (2.3.0)

# %%
from urllib.request import urlopen
import json

response = urlopen('https://api.openf1.org/v1/race_control?meeting_key%3E=latest')
data = json.loads(response.read().decode('utf-8'))
print(data)
# Out:
# [{'session_key': 9686, 'meeting_key': 1254, 'date': '2025-03-14T01:30:00+00:00', 'category': 'Flag', 'flag': 'GREEN', 'lap_number': None, 'message': 'GREEN LIGHT - PIT EXIT OPEN', 'driver_number': None, 'scope': 'Track', 'sector': None}, {'session_key': 9686, 'meeting_key': 1254, 'date': '2025-03-14T01:48:31+00:00', 'category': 'Flag', 'flag': 'RED', 'lap_number': None, 'message': 'RED FLAG', 'driver_number': None, 'scope': 'Track', 'sector': None}, {'session_key': 9686, 'meeting_key': 1254, 'date': '2025-03-14T01:53:58+00:00', 'category': 'Other', 'flag': None, 'lap_number': None, 'message': 'SESSION WILL RESUME AT 12:55', 'driver_number': None, 'scope': None, 'sector': None}, {'session_key': 9686, 'meeting_key': 1254, 'date': '2025-03-14T01:54:03+00:00', 'category': 'Flag', 'flag': 'CLEAR', 'lap_number': None, 'message': 'TRACK CLEAR', 'driver_number': None, 'scope': 'Track', 'sector': None}, {'session_key': 9686, 'meeting_key': 1254, 'date': '2025-03-14T01:54:05+00:00', 'category': 'Drs', 'flag': None, 'lap_number': None, 'message': 'DRS ENABLED', 'driver_number': None, 'scope': None, 'sector': None}, {'session_key': 9686, 'meeting_key': 1254, 'date': '2025-03-14T01:55:00+00:00', 'category': 'Flag', 'flag': 'GREEN', 'lap_number': None, 'message': 'GREEN LIGHT - PIT EXIT OPEN', 'driver_number': None, 'scope': 'Track', 'sector': None}, {'session_key': 9686, 'meeting_key': 1254, 'date': '2025-03-14T01:58:51+00:00', 'category': 'Flag', 'flag': 'DOUBLE YELLOW', 'lap_number': None, 'message': 'DOUBLE YELLOW IN TRACK SECTOR 3', 'driver_number': None, 'scope': 'Sector', 'sector': 3}, {'session_key': 9686, 'meeting_key': 1254, 'date': '2025-03-14T01:58:52+00:00', 'category': 'Other', 'flag': None, 'lap_number': None, 'message': 'DRS DISABLED IN ZONE 4', 'driver_number': None, 'scope': None, 'sector': None}, {'session_key': 9686, 'meeting_key': 1254, 'date': '2025-03-14T01:58:54+00:00', 'category': 'Flag', 'flag': 'CLEAR', 'lap_number': None, 'message': 'CLEAR IN TRACK SECTOR 3', 'driver_number': None, 'scope': 'Sector', 'sector': 3}, {'session_key': 9686, 'meeting_key': 1254, 'date': '2025-03-14T01:58:54+00:00', 'category': 'Other', 'flag': None, 'lap_number': None, 'message': 'DRS ENABLED IN ZONE 4', 'driver_number': None, 'scope': None, 'sector': None}]

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
df
# Out:
#    session_key  meeting_key                       date category  \
# 0         9686         1254  2025-03-14T01:30:00+00:00     Flag
# 1         9686         1254  2025-03-14T01:48:31+00:00     Flag
# 2         9686         1254  2025-03-14T01:53:58+00:00    Other
# 3         9686         1254  2025-03-14T01:54:03+00:00     Flag
# 4         9686         1254  2025-03-14T01:54:05+00:00      Drs
# 5         9686         1254  2025-03-14T01:55:00+00:00     Flag
# 6         9686         1254  2025-03-14T01:58:51+00:00     Flag
# 7         9686         1254  2025-03-14T01:58:52+00:00    Other
# 8         9686         1254  2025-03-14T01:58:54+00:00     Flag
# 9         9686         1254  2025-03-14T01:58:54+00:00    Other
#
#             flag lap_number                          message driver_number  \
# 0          GREEN       None      GREEN LIGHT - PIT EXIT OPEN          None
# 1            RED       None                         RED FLAG          None
# 2           None       None     SESSION WILL RESUME AT 12:55          None
# 3          CLEAR       None                      TRACK CLEAR          None
# 4           None       None                      DRS ENABLED          None
# 5          GREEN       None      GREEN LIGHT - PIT EXIT OPEN          None
# 6  DOUBLE YELLOW       None  DOUBLE YELLOW IN TRACK SECTOR 3          None
# 7           None       None           DRS DISABLED IN ZONE 4          None
# 8          CLEAR       None          CLEAR IN TRACK SECTOR 3          None
# 9           None       None            DRS ENABLED IN ZONE 4          None
#
#     scope  sector
# 0   Track     NaN
# 1   Track     NaN
# 2    None     NaN
# 3   Track     NaN
# 4    None     NaN
# 5   Track     NaN
# 6  Sector     3.0
# 7    None     NaN
# 8  Sector     3.0
# 9    None     NaN

# %%
import json
import time
from urllib.request import urlopen, URLError
import pandas as pd
from typing import Dict, List, Optional

# Constants
BASE_URL = "https://api.openf1.org/v1/race_control"
REFRESH_INTERVAL = 5  # seconds

def fetch_f1_data(url: str) -> Optional[List[Dict]]:
    """
    Fetch data from OpenF1 API
    """
    try:
        response = urlopen(f"{url}?meeting_key%3E=latest")
        return json.loads(response.read().decode("utf-8"))
    except (URLError, json.JSONDecodeError) as e:
        print(f"Error fetching data: {e}")
        return None

def process_f1_data(data: List[Dict]) -> Optional[pd.DataFrame]:
    """
    Process F1 data into a pandas DataFrame
    """
    if not data:
        return None

    return pd.DataFrame(data)

def display_f1_data(df: pd.DataFrame) -> None:
    """
    Display F1 data with formatted output
    """
    if df is not None and not df.empty:
        print("\nLatest F1 Race Control Messages:")
        print(df[['message', 'category', 'flag', 'scope']].to_string())
    else:
        print("No data available")

def monitor_f1_data():
    """
    Continuously monitor F1 data
    """
    print("Starting F1 Live Data Monitor...")

    while True:
        data = fetch_f1_data(BASE_URL)
        if data:
            df = process_f1_data(data)
            display_f1_data(df)

        print(f"\nRefreshing in {REFRESH_INTERVAL} seconds...")
        time.sleep(REFRESH_INTERVAL)

if __name__ == "__main__":
    try:
        monitor_f1_data()
    except KeyboardInterrupt:
        print("\nStopping F1 Live Data Monitor...")
# Out:
# Starting F1 Live Data Monitor...
#
# Latest F1 Race Control Messages:
#                            message category           flag   scope
# 0      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                         RED FLAG     Flag            RED   Track
# 2     SESSION WILL RESUME AT 12:55    Other           None    None
# 3                      TRACK CLEAR     Flag          CLEAR   Track
# 4                      DRS ENABLED      Drs           None    None
# 5      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6  DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7           DRS DISABLED IN ZONE 4    Other           None    None
# 8          CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9            DRS ENABLED IN ZONE 4    Other           None    None
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                            message category           flag   scope
# 0      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                         RED FLAG     Flag            RED   Track
# 2     SESSION WILL RESUME AT 12:55    Other           None    None
# 3                      TRACK CLEAR     Flag          CLEAR   Track
# 4                      DRS ENABLED      Drs           None    None
# 5      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6  DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7           DRS DISABLED IN ZONE 4    Other           None    None
# 8          CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9            DRS ENABLED IN ZONE 4    Other           None    None
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                            message category           flag   scope
# 0      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                         RED FLAG     Flag            RED   Track
# 2     SESSION WILL RESUME AT 12:55    Other           None    None
# 3                      TRACK CLEAR     Flag          CLEAR   Track
# 4                      DRS ENABLED      Drs           None    None
# 5      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6  DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7           DRS DISABLED IN ZONE 4    Other           None    None
# 8          CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9            DRS ENABLED IN ZONE 4    Other           None    None
#
# Refreshing in 5 seconds...
#
# Stopping F1 Live Data Monitor...

# %%
import json
import time
import os
from typing import Dict, List, Optional
from urllib.request import URLError, urlopen
from atproto import Client
import pandas as pd

# Constants
BASE_URL = "https://api.openf1.org/v1/race_control"
HASHTAGS = "#f1 #formula1 #live #AusGP #AustralianGP"
REFRESH_INTERVAL = 5  # seconds


FLAG_EMOJIS = {
    "YELLOW": "⚠️",
    "RED": "🔴",
    "GREEN": "🟢",
    "BLUE": "🔵",
    "CHEQUERED": "🏁",
    "BLACK": "⚫",
    "BLACK_AND_ORANGE": "🟧",
    "BLACK_AND_WHITE": "⬛⬜",
    "WHITE": "⚪",
    "DOUBLE_YELLOW": "⚠️⚠️"
}

CATEGORY_EMOJIS = {
    "SECTOR": "📍",
    "TRACK": "🛣️",
    "FLAG": "🚩",
    "DRIVER": "🏎️",
    "CAR": "🏎️",
    "RACE_CONTROL": "📊",
    "SAFETY_CAR": "🚨",
    "DRS": "💨",
    "WARNING": "⚠️",
    "TRACK_STATUS": "🏁"
}
def fetch_f1_data(url: str) -> Optional[List[Dict]]:
    """
    Fetch data from OpenF1 API
    """
    try:
        response = urlopen(f"{url}?meeting_key%3E=latest")
        return json.loads(response.read().decode("utf-8"))
    except (URLError, json.JSONDecodeError) as e:
        print(f"Error fetching data: {e}")
        return None

def process_f1_data(data: List[Dict]) -> Optional[pd.DataFrame]:
    """
    Process F1 data into a pandas DataFrame
    """
    if not data:
        return None
    return pd.DataFrame(data)

def display_f1_data(df: pd.DataFrame) -> None:
    """
    Display F1 data with formatted output
    """
    if df is not None and not df.empty:
        print("\nLatest F1 Race Control Messages:")
        print(df[["message", "category", "flag", "scope"]].to_string())
    else:
        print("No data available")

def format_bluesky_message(df: pd.DataFrame) -> str:
    """Format F1 data for Bluesky post"""
    if df is None or df.empty:
        return "No F1 updates available"

    latest_message = df.iloc[0]
    return f"🏎 F1 Update:\n{latest_message['message']}\nCategory: {latest_message['category']}\nFlag: {latest_message['flag']}\nScope: {latest_message['scope']}"

def post_to_bluesky(client: Client, message: str) -> None:
    """Post message to Bluesky"""
    try:
        client.send_post(text=message)
    except Exception as e:
        print(f"Error posting to Bluesky: {e}")

def monitor_f1_data(bluesky_client: Client):
    """
    Continuously monitor F1 data and post updates to Bluesky
    """
    print("Starting F1 Live Data Monitor with Bluesky integration...")
    previous_messages = set()

    while True:
        data = fetch_f1_data(BASE_URL)
        if data:
            df = process_f1_data(data)
            display_f1_data(df)

            if df is not None and not df.empty:
                current_messages = set(
                    tuple(row) for row in
                    df[['message', 'category', 'flag', 'scope']].itertuples(index=False)
                )

                new_messages = current_messages - previous_messages

                for message in new_messages:
                    flag_emoji = FLAG_EMOJIS.get(message[2], "")
                    category_emoji = CATEGORY_EMOJIS.get(message[1], "")

                    bluesky_post = f"{category_emoji} {flag_emoji} F1 Update:\n{message[0]}\nCategory: {message[1]}\nFlag: {message[2]}\nScope: {message[3]}\n\n{HASHTAGS}"
                    post_to_bluesky(bluesky_client, bluesky_post)

                previous_messages = current_messages

        print(f"\nRefreshing in {REFRESH_INTERVAL} seconds...")
        time.sleep(REFRESH_INTERVAL)


if __name__ == "__main__":
    try:
        # Setup Bluesky client
        bluesky_client = Client()
        bluesky_client.login( 'tracing.insights+live@gmail.com', 'Rg2F8XSw!26aZeZ'
            # os.environ.get("BLUESKY_USERNAME"),
            # os.environ.get("BLUESKY_PASSWORD")
        )

        # Start monitoring with Bluesky integration
        monitor_f1_data(bluesky_client)
    except KeyboardInterrupt:
        print("\nStopping F1 Live Data Monitor...")
# Out:
# Starting F1 Live Data Monitor with Bluesky integration...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Stopping F1 Live Data Monitor...

# %%
import json
import os
import time
from typing import Dict, List, Optional
from urllib.request import URLError, urlopen

import pandas as pd
from atproto import Client

# Constants
BASE_URL = "https://api.openf1.org/v1/race_control"
HASHTAGS = "#f1 #formula1 #live #AusGP #AustralianGP"
REFRESH_INTERVAL = 5  # seconds


FLAG_EMOJIS = {
    "YELLOW": "⚠️",
    "RED": "🔴",
    "GREEN": "🟢",
    "BLUE": "🔵",
    "CHEQUERED": "🏁",
    "BLACK": "⚫",
    "BLACK_AND_ORANGE": "🟧",
    "BLACK_AND_WHITE": "⬛⬜",
    "WHITE": "⚪",
    "DOUBLE_YELLOW": "⚠️⚠️",
}

CATEGORY_EMOJIS = {
    "SECTOR": "📍",
    "TRACK": "🛣️",
    "FLAG": "🚩",
    "DRIVER": "🏎️",
    "CAR": "🏎️",
    "RACE_CONTROL": "📊",
    "SAFETY_CAR": "🚨",
    "DRS": "💨",
    "WARNING": "⚠️",
    "TRACK_STATUS": "🏁",
}


def fetch_f1_data(url: str) -> Optional[List[Dict]]:
    """
    Fetch data from OpenF1 API
    """
    try:
        response = urlopen(f"{url}?meeting_key%3E=latest")
        return json.loads(response.read().decode("utf-8"))
    except (URLError, json.JSONDecodeError) as e:
        print(f"Error fetching data: {e}")
        return None


def process_f1_data(data: List[Dict]) -> Optional[pd.DataFrame]:
    """
    Process F1 data into a pandas DataFrame
    """
    if not data:
        return None
    return pd.DataFrame(data)


def display_f1_data(df: pd.DataFrame) -> None:
    """
    Display F1 data with formatted output
    """
    if df is not None and not df.empty:
        print("\nLatest F1 Race Control Messages:")
        print(df[["message", "category", "flag", "scope"]].to_string())
    else:
        print("No data available")


def format_bluesky_message(df: pd.DataFrame) -> str:
    """Format F1 data for Bluesky post"""
    if df is None or df.empty:
        return "No F1 updates available"

    latest_message = df.iloc[0]
    return f"🏎 F1 Update:\n{latest_message['message']}\nCategory: {latest_message['category']}\nFlag: {latest_message['flag']}\nScope: {latest_message['scope']}"


def create_hashtag_facets(text: str) -> list:
    facets = []
    for word in text.split():
        if word.startswith("#"):
            start = text.index(word)
            facets.append(
                {
                    "index": {"byteStart": start, "byteEnd": start + len(word)},
                    "features": [
                        {
                            "$type": "app.bsky.richtext.facet#tag",
                            "tag": word[1:],  # Remove # prefix
                        }
                    ],
                }
            )
    return facets


def post_to_bluesky(client: Client, message: str) -> None:
    """Post message to Bluesky with clickable hashtags"""
    try:
        facets = create_hashtag_facets(message)
        client.send_post(text=message, facets=facets)
    except Exception as e:
        print(f"Error posting to Bluesky: {e}")


def monitor_f1_data(bluesky_client: Client):
    """
    Continuously monitor F1 data and post updates to Bluesky
    """
    print("Starting F1 Live Data Monitor with Bluesky integration...")
    previous_messages = set()

    while True:
        data = fetch_f1_data(BASE_URL)
        if data:
            df = process_f1_data(data)
            display_f1_data(df)

            if df is not None and not df.empty:
                current_messages = set(
                    tuple(row)
                    for row in df[["message", "category", "flag", "scope"]].itertuples(
                        index=False
                    )
                )

                new_messages = current_messages - previous_messages

                for message in new_messages:
                    flag_emoji = FLAG_EMOJIS.get(message[2], "")
                    category_emoji = CATEGORY_EMOJIS.get(message[1], "")

                    bluesky_post = f"{category_emoji} {flag_emoji} F1 Update:\n{message[0]}\nCategory: {message[1]}\nFlag: {message[2]}\nScope: {message[3]}\n\n{HASHTAGS}"
                    post_to_bluesky(bluesky_client, bluesky_post)

                previous_messages = current_messages

        print(f"\nRefreshing in {REFRESH_INTERVAL} seconds...")
        time.sleep(REFRESH_INTERVAL)


if __name__ == "__main__":
    try:
        # Setup Bluesky client
        bluesky_client = Client()
        bluesky_client.login(
            "tracing.insights+live@gmail.com",
            "Rg2F8XSw!26aZeZ",
            # os.environ.get("BLUESKY_USERNAME"),
            # os.environ.get("BLUESKY_PASSWORD")
        )

        # Start monitoring with Bluesky integration
        monitor_f1_data(bluesky_client)
    except KeyboardInterrupt:
        print("\nStopping F1 Live Data Monitor...")
# Out:
# Starting F1 Live Data Monitor with Bluesky integration...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
#
# Latest F1 Race Control Messages:
#                             message category           flag   scope
# 0       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 1                          RED FLAG     Flag            RED   Track
# 2      SESSION WILL RESUME AT 12:55    Other           None    None
# 3                       TRACK CLEAR     Flag          CLEAR   Track
# 4                       DRS ENABLED      Drs           None    None
# 5       GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
# 6   DOUBLE YELLOW IN TRACK SECTOR 3     Flag  DOUBLE YELLOW  Sector
# 7            DRS DISABLED IN ZONE 4    Other           None    None
# 8           CLEAR IN TRACK SECTOR 3     Flag          CLEAR  Sector
# 9             DRS ENABLED IN ZONE 4    Other           None    None
# 10                         RED FLAG     Flag            RED   Track
# 11      SESSION WILL RESUME AT13:19    Other           None    None
# 12                      TRACK CLEAR     Flag          CLEAR   Track
# 13                      DRS ENABLED      Drs           None    None
# 14      GREEN LIGHT - PIT EXIT OPEN     Flag          GREEN   Track
#
# Refreshing in 5 seconds...
